# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
dataset =load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df1=df[['job_title_short', 'job_location','salary_rate']].sort_values(by='salary_rate',ascending=True).head(10)
df2 = df[['salary_hour_avg', 'job_country']].sort_values(by='salary_hour_avg',ascending=True).head(10)

# %%
df1
# Out:
#              job_title_short             job_location salary_rate
# 374178          Data Analyst            Arlington, TX         day
# 68466         Cloud Engineer  Canberra ACT, Australia         day
# 611751         Data Engineer                 Anywhere         day
# 77506    Senior Data Analyst                 Anywhere         day
# 474402          Data Analyst           Montevallo, AL         day
# 274111      Business Analyst               Odessa, TX         day
# 235305         Data Engineer            Englewood, CO         day
# 100301         Data Engineer             New York, NY         day
# 195263          Data Analyst             New York, NY         day
# 214692  Senior Data Engineer              Orlando, FL        hour

# %%
df2
# Out:
#         salary_hour_avg    job_country
# 488236              8.0  United States
# 661330              8.0         Taiwan
# 88185               8.0  United States
# 610609              8.0          Sudan
# 210918              8.5  United States
# 33220               8.5  United States
# 709140              9.0  United States
# 569914              9.0          Sudan
# 630139              9.0  United States
# 208353              9.0       Zimbabwe

# %%
df1.merge(df1,on='job_location')
# Out:
#        job_title_short_x             job_location salary_rate_x  \
# 0           Data Analyst            Arlington, TX           day
# 1         Cloud Engineer  Canberra ACT, Australia           day
# 2          Data Engineer                 Anywhere           day
# 3          Data Engineer                 Anywhere           day
# 4    Senior Data Analyst                 Anywhere           day
# 5    Senior Data Analyst                 Anywhere           day
# 6           Data Analyst           Montevallo, AL           day
# 7       Business Analyst               Odessa, TX           day
# 8          Data Engineer            Englewood, CO           day
# 9          Data Engineer             New York, NY           day
# 10         Data Engineer             New York, NY           day
# 11          Data Analyst             New York, NY           day
# 12          Data Analyst             New York, NY           day
# 13  Senior Data Engineer              Orlando, FL          hour
#
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df5=pd.read_csv('https://lukeb.co/software_csv',index_col='job_posted_month')
df5
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_merged=df5.merge(df5,on='job_posted_month')

# %%
top_5=(df_merged.sum()
       .sort_values(ascending=False)
       .head(5)
       .index.
       to_list())
top_5
# Out:
# ['Front-End Developer_x',
#  'Front-End Developer_y',
#  'Back-End Developer_x',
#  'Back-End Developer_y',
#  'Full-Stack Developer_x']

# %%
df_merged[top_5].plot(kind='line')
plt.title('monthly job postings')
plt.xlabel('Month')
plt.ylabel('Number of postings')
plt.xticks(rotation=45)
plt.legend(loc='upper center')
plt.show()

# %%
# You need to pass DataFrames or Series to pd.concat, not strings.
# For example, to concatenate two DataFrames vertically:
# pd.concat([df1, df2])

# If you want to select the January job postings from df5:
job_posting_jan = df5.loc[['January']]
job_posting_jan
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df['job_posted_month']=df['job_posted_date'].dt.strftime('%B')

# %%
months=df['job_posted_month'].unique()
dict_months={month :df[df['job_posted_month']==month] for month in months}

# %%
dict_months['January']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_p=pd.concat([dict_months['January'],dict_months['February'],dict_months['March']],ignore_index=True)

# %%
df_p['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>
